# %%
# --- Standard Library ---
from pathlib import Path

# --- Third-Party Libraries ---
import pandas as pd
import sidetable as stb

# %%
# Set the maximum number of columns to display 
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Leitura inicial e concatenação dos dados

# %%
all_data_dict = {}

# %%
BASE_DIR = Path("../data/raw")  

# Dictionary of files
csv_files = {
    'srag_19': "INFLUD19-26-06-2025.csv",
    'srag_20': "INFLUD20-26-06-2025.csv",
    'srag_21': "INFLUD21-26-06-2025.csv",
    'srag_22': "INFLUD22-26-06-2025.csv",
    'srag_23': "INFLUD23-26-06-2025.csv",
    'srag_24': "INFLUD24-26-06-2025.csv",
    'srag_25': "INFLUD25-22-09-2025.csv",
}

all_data_dict = {}

for key, filename in csv_files.items():
    file_path = BASE_DIR / filename  
    all_data_dict[key] = pd.read_csv(file_path, sep=';', low_memory=False)

# Test
print(all_data_dict['srag_19'].head())
# Out:
#      NU_NOTIFIC  DT_NOTIFIC  SEM_NOT  DT_SIN_PRI  SEM_PRI SG_UF_NOT  \
# 0  315478195042  2019-01-10        2  2019-01-06        2        MG
# 1  315478195276  2019-01-03        1  2019-01-01        1        SP
# 2  315478207219  2019-01-02        1  2018-12-31        1        PE
# 3  315478211086  2019-01-10        2  2019-01-07        2        SP
# 4  315478212765  2019-01-11        2  2019-01-06        2        PE
#
#           ID_REGIONA  CO_REGIONA      ID_MUNICIP  CO_MUN_NOT CS_SEXO  \
# 0     BELO HORIZONTE      1449.0  BELO HORIZONTE    310620.0       M
# 1      GVE I CAPITAL      1331.0       SAO PAULO    355030.0       F
# 2                001      1497.0          RECIFE    261160.0       M
# 3  GVE XVII CAMPINAS      1342.0        CAMPINAS    350950.0       F
# 4                004      1499.0         CARUARU    260410.0       F
#
#       DT_NASC  NU_IDADE_N  TP_IDADE  COD_IDADE  CS_GESTANT  CS_RACA CS_ETINIA  \
# 0  1988-03-17          30         3       3030           6      1.0       NaN
# 1  2018-05-30           7         2       2007           6      1.0       NaN
# 2  2017-05-07           1         3       3001           6      4.0       NaN
# 3  2018-07-15           5         2       2005           6      1.0       NaN
# 4  2018-09-15           3         2       2003           6      4.0       NaN
#
#    CS_ESCOL_N ID_PAIS  CO_PAIS SG_UF         ID_RG_RESI  CO_RG_RESI  \
# 0         2.0  BRASIL      1.0    MG     BELO HORIZONTE      1449.0
# 1         5.0  BRASIL      1.0    SP      GVE I CAPITAL      1331.0
# 2         5.0  BRASIL      1.0    PE                012      5558.0
# 3         5.0  BRASIL      1.0    SP  GVE XVII CAMPINAS      1342.0
# 4         5.0  BRASIL      1.0    PE                004      1499.0
#
#            ID_MN_RESI  CO_MUN_RES  CS_ZONA  NOSOCOMIAL  AVE_SUINO  FEBRE  \
# 0  RIBEIRAO DAS NEVES    315460.0      1.0         2.0        2.0    1.0
# 1           SAO PAULO    355030.0      1.0         NaN        NaN    1.0
# 2              GOIANA    260620.0      1.0         9.0        9.0    1.0
# 3            CAMPINAS    350950.0      1.0         2.0        2.0    1.0
# 4         BELO JARDIM    260170.0      1.0         9.0        2.0    1.0
#
#    TOSSE  GARGANTA  DISPNEIA  DESC_RESP  SATURACAO  DIARREIA  VOMITO  \
# 0    1.0       2.0       1.0        1.0        1.0       2.0     2.0
# 1    1.0       2.0       1.0        1.0        1.0       2.0     2.0
# 2    1.0       2.0       1.0        1.0        1.0       2.0     2.0
# 3    1.0       9.0       1.0        1.0        1.0       2.0     2.0
# 4    2.0       2.0       1.0        1.0        1.0       9.0     9.0
#
#    OUTRO_SIN        OUTRO_DES  FATOR_RISC  PUERPERA  CARDIOPATI  HEMATOLOGI  \
# 0        1.0  DERRAME PLEURAL         NaN       NaN         NaN         NaN
# 1        2.0              NaN         NaN       NaN         NaN         NaN
# 2        2.0              NaN         NaN       NaN         NaN         NaN
# 3        2.0              NaN         NaN       NaN         NaN         NaN
# 4        2.0              NaN         NaN       NaN         NaN         NaN
#
#    SIND_DOWN  HEPATICA  ASMA  DIABETES  NEUROLOGIC  PNEUMOPATI  IMUNODEPRE  \
# 0        NaN       NaN   NaN       NaN         NaN         NaN         NaN
# 1        NaN       NaN   NaN       NaN         NaN         NaN         NaN
# 2        NaN       NaN   NaN       NaN         NaN         NaN         NaN
# 3        NaN       NaN   NaN       NaN         NaN         NaN         NaN
# 4        NaN       NaN   NaN       NaN         NaN         NaN         NaN
#
#    RENAL  OBESIDADE  OBES_IMC  OUT_MORBI MORB_DESC  TABAG  VACINA DT_UT_DOSE  \
# 0    NaN        NaN       NaN        NaN       NaN    NaN     2.0        NaN
# 1    NaN        NaN       NaN        NaN       NaN    NaN     2.0        NaN
# 2    NaN        NaN       NaN        NaN       NaN    NaN     2.0        NaN
# 3    NaN        NaN       NaN        NaN       NaN    NaN     2.0        NaN
# 4    NaN        NaN       NaN        NaN       NaN    NaN     2.0        NaN
#
#    MAE_VAC DT_VAC_MAE  M_AMAMENTA DT_DOSEUNI DT_1_DOSE DT_2_DOSE  ANTIVIRAL  \
# 0      NaN        NaN         NaN        NaN       NaN       NaN        1.0
# 1      NaN        NaN         NaN        NaN       NaN       NaN        1.0
# 2      NaN        NaN         NaN        NaN       NaN       NaN        2.0
# 3      NaN        NaN         NaN        NaN       NaN       NaN        1.0
# 4      9.0        NaN         9.0        NaN       NaN       NaN        2.0
#
#    TP_ANTIVIR OUT_ANTIV  DT_ANTIVIR  HOSPITAL  DT_INTERNA SG_UF_INTE  \
# 0         1.0       NaN  2019-01-07       1.0  2019-01-06         MG
# 1         1.0       NaN  2019-01-01       1.0  2019-01-01         SP
# 2         NaN       NaN         NaN       1.0  2019-01-02         PE
# 3         1.0       NaN  2019-01-10       1.0  2019-01-10         SP
# 4         NaN       NaN         NaN       1.0  2019-01-13         PE
#
#           ID_RG_INTE  CO_RG_INTE      ID_MN_INTE  CO_MU_INTE  \
# 0     BELO HORIZONTE      1449.0  BELO HORIZONTE    310620.0
# 1      GVE I CAPITAL      1331.0       SAO PAULO    355030.0
# 2                001      1497.0          RECIFE    261160.0
# 3  GVE XVII CAMPINAS      1342.0        CAMPINAS    350950.0
# 4                004      1499.0         CARUARU    260410.0
#
#                                    NM_UN_INTE  UTI   DT_ENTUTI DT_SAIDUTI  \
# 0         UNIDADE DE PRONTO ATENDIMENTO LESTE  2.0         NaN        NaN
# 1                        HOSP MUN M BOI MIRIM  1.0  2019-01-01        NaN
# 2                                        IMIP  2.0         NaN        NaN
# 3  HOSPITAL MUNICIPAL DR MARIO GATTI CAMPINAS  1.0  2019-01-10        NaN
# 4                    HOSPITAL MESTRE VITALINO  9.0         NaN        NaN
#
#    SUPORT_VEN  RAIOX_RES        RAIOX_OUT    DT_RAIOX  AMOSTRA   DT_COLETA  \
# 0         2.0        5.0  DERRAME PLEURAL  2019-01-06      2.0         NaN
# 1         2.0        2.0              NaN  2019-01-01      1.0  2019-01-02
# 2         2.0        1.0              NaN  2019-01-02      1.0  2019-01-02
# 3         2.0        2.0              NaN         NaN      1.0  2019-01-10
# 4         9.0        NaN              NaN         NaN      1.0  2019-01-14
#
#    TP_AMOSTRA          OUT_AMOST  PCR_RESUL      DT_PCR  POS_PCRFLU  \
# 0         NaN                NaN        4.0         NaN         NaN
# 1         1.0                NaN        2.0  2019-01-08         NaN
# 2         1.0                NaN        2.0  2019-03-10         NaN
# 3         4.0  SECRECAO TRAQUEAL        2.0  2019-02-04         NaN
# 4         3.0                NaN        2.0  2019-05-03         NaN
#
#    TP_FLU_PCR  PCR_FLUASU FLUASU_OUT  PCR_FLUBLI FLUBLI_OUT  POS_PCROUT  \
# 0         NaN         NaN        NaN         NaN        NaN         NaN
# 1         NaN         NaN        NaN         NaN        NaN         NaN
# 2         NaN         NaN        NaN         NaN        NaN         NaN
# 3         NaN         NaN        NaN         NaN        NaN         NaN
# 4         NaN         NaN        NaN         NaN        NaN         NaN
#
#    PCR_VSR  PCR_PARA1  PCR_PARA2  PCR_PARA3  PCR_PARA4  PCR_ADENO  PCR_METAP  \
# 0      NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 1      NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 2      NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 3      NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 4      NaN        NaN        NaN        NaN        NaN        NaN        NaN
#
#    PCR_BOCA  PCR_RINO  PCR_OUTRO DS_PCR_OUT  CLASSI_FIN CLASSI_OUT  CRITERIO  \
# 0       NaN       NaN        NaN        NaN         4.0        NaN       3.0
# 1       NaN       NaN        NaN        NaN         4.0        NaN       1.0
# 2       NaN       NaN        NaN        NaN         4.0        NaN       1.0
# 3       NaN       NaN        NaN        NaN         2.0        NaN       1.0
# 4       NaN       NaN        NaN        NaN         4.0        NaN       1.0
#
#    EVOLUCAO  DT_EVOLUCA  DT_ENCERRA   DT_DIGITA  HISTO_VGM PAIS_VGM  \
# 0       1.0  2019-01-25  2019-02-15  2019-03-14          0      NaN
# 1       1.0  2019-03-05  2019-01-21         NaN          0      NaN
# 2       1.0  2019-02-12  2019-05-31         NaN          0      NaN
# 3       1.0  2019-01-29  2019-02-04         NaN          0      NaN
# 4       2.0  2019-01-13  2019-05-21         NaN          0      NaN
#
#    CO_PS_VGM LO_PS_VGM DT_VGM DT_RT_VGM  PCR_SARS2 PAC_COCBO PAC_DSCBO  \
# 0        NaN       NaN    NaN       NaN        NaN       NaN       NaN
# 1        NaN       NaN    NaN       NaN        NaN       NaN       NaN
# 2        NaN       NaN    NaN       NaN        NaN       NaN       NaN
# 3        NaN       NaN    NaN       NaN        NaN       NaN       NaN
# 4        NaN       NaN    NaN       NaN        NaN       NaN       NaN
#
#    OUT_ANIM  DOR_ABD  FADIGA  PERD_OLFT  PERD_PALA  TOMO_RES TOMO_OUT DT_TOMO  \
# 0       NaN      NaN     NaN        NaN        NaN       NaN      NaN     NaN
# 1       NaN      NaN     NaN        NaN        NaN       NaN      NaN     NaN
# 2       NaN      NaN     NaN        NaN        NaN       NaN      NaN     NaN
# 3       NaN      NaN     NaN        NaN        NaN       NaN      NaN     NaN
# 4       NaN      NaN     NaN        NaN        NaN       NaN      NaN     NaN
#
#    TP_TES_AN   DT_RES_AN  RES_AN  POS_AN_FLU  TP_FLU_AN  POS_AN_OUT  AN_SARS2  \
# 0        1.0         NaN     4.0         NaN        NaN         NaN       NaN
# 1        1.0         NaN     4.0         NaN        NaN         NaN       NaN
# 2        1.0  2019-01-10     2.0         NaN        NaN         NaN       NaN
# 3        1.0  2019-01-10     1.0         2.0        NaN         1.0       NaN
# 4        1.0         NaN     4.0         NaN        NaN         NaN       NaN
#
#    AN_VSR  AN_PARA1  AN_PARA2  AN_PARA3  AN_ADENO  AN_OUTRO DS_AN_OUT  \
# 0     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3     1.0       NaN       NaN       NaN       NaN       NaN       NaN
# 4     NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    TP_AM_SOR  SOR_OUT DT_CO_SOR  TP_SOR  OUT_SOR DT_RES  RES_IGG  RES_IGM  \
# 0        NaN      NaN       NaN     NaN      NaN    NaN      NaN      NaN
# 1        NaN      NaN       NaN     NaN      NaN    NaN      NaN      NaN
# 2        NaN      NaN       NaN     NaN      NaN    NaN      NaN      NaN
# 3        NaN      NaN       NaN     NaN      NaN    NaN      NaN      NaN
# 4        NaN      NaN       NaN     NaN      NaN    NaN      NaN      NaN
#
#    RES_IGA  POV_CT TP_POV_CT  TEM_CPF  ESTRANG  VACINA_COV DOSE_1_COV  \
# 0      NaN     NaN       NaN      NaN      NaN         NaN        NaN
# 1      NaN     NaN       NaN      NaN      NaN         NaN        NaN
# 2      NaN     NaN       NaN      NaN      NaN         NaN        NaN
# 3      NaN     NaN       NaN      NaN      NaN         NaN        NaN
# 4      NaN     NaN       NaN      NaN      NaN         NaN        NaN
#
#   DOSE_2_COV DOSE_REF DOSE_2REF DOSE_ADIC DOS_RE_BI FAB_COV_1 FAB_COV_2  \
# 0        NaN      NaN       NaN       NaN       NaN       NaN       NaN
# 1        NaN      NaN       NaN       NaN       NaN       NaN       NaN
# 2        NaN      NaN       NaN       NaN       NaN       NaN       NaN
# 3        NaN      NaN       NaN       NaN       NaN       NaN       NaN
# 4        NaN      NaN       NaN       NaN       NaN       NaN       NaN
#
#   FAB_COVRF FAB_COVRF2 FAB_ADIC FAB_RE_BI LOTE_1_COV LOTE_2_COV LOTE_REF  \
# 0       NaN        NaN      NaN       NaN        NaN        NaN      NaN
# 1       NaN        NaN      NaN       NaN        NaN        NaN      NaN
# 2       NaN        NaN      NaN       NaN        NaN        NaN      NaN
# 3       NaN        NaN      NaN       NaN        NaN        NaN      NaN
# 4       NaN        NaN      NaN       NaN        NaN        NaN      NaN
#
#   LOTE_REF2 LOTE_ADIC LOT_RE_BI  FNT_IN_COV  TRAT_COV  TIPO_TRAT  DT_TRT_COV  \
# 0       NaN       NaN       NaN         NaN       NaN        NaN         NaN
# 1       NaN       NaN       NaN         NaN       NaN        NaN         NaN
# 2       NaN       NaN       NaN         NaN       NaN        NaN         NaN
# 3       NaN       NaN       NaN         NaN       NaN        NaN         NaN
# 4       NaN       NaN       NaN         NaN       NaN        NaN         NaN
#
#    OUT_TRAT  SURTO_SG  CO_DETEC  VG_OMS  VG_OMSOUT  VG_LIN  VG_MET  VG_METOUT  \
# 0       NaN       NaN       NaN     NaN        NaN     NaN     NaN        NaN
# 1       NaN       NaN       NaN     NaN        NaN     NaN     NaN        NaN
# 2       NaN       NaN       NaN     NaN        NaN     NaN     NaN        NaN
# 3       NaN       NaN       NaN     NaN        NaN     NaN     NaN        NaN
# 4       NaN       NaN       NaN     NaN        NaN     NaN     NaN        NaN
#
#    VG_DTRES  VG_ENC  VG_REINF  VG_CODEST  REINF
# 0       NaN     NaN       NaN        NaN    NaN
# 1       NaN     NaN       NaN        NaN    NaN
# 2       NaN     NaN       NaN        NaN    NaN
# 3       NaN     NaN       NaN        NaN    NaN
# 4       NaN     NaN       NaN        NaN    NaN

# %% [markdown]
# Checando se existem colunas divergentes entre uma base e outra

# %%
# Pegamos as colunas do primeiro DataFrame como referência
cols_ref = list(all_data_dict[list(all_data_dict.keys())[0]].columns)

# Checamos se todos os DataFrames têm as mesmas colunas
if all(list(df.columns) == cols_ref for df in all_data_dict.values()):
    print("✅ All DataFrames have the same columns")
else:
    print("⚠️ Some DataFrames have different columns")
# Out:
# ✅ All DataFrames have the same columns

# %% [markdown]
# ## 📊 Seleção de Colunas e Justificativa
#
# O conjunto de dados possui **194 colunas**. Após análise, selecionamos apenas as colunas essenciais para as métricas solicitadas, garantindo que cada cálculo seja baseado em informações confiáveis. As variáveis selecionadas precisam contemplar a necessidade de calcular cada um dos indicadores:
#
# #### 🔹 Taxa de Aumento de Casos
# #### 🔹 Taxa de Mortalidade
# #### 🔹 Taxa de Ocupação de UTI
# #### 🔹 Taxa de Vacinação
#
# #### Para os indicadores, foram selecionadas as colunas:
#
# - `NM_PACIENT` → nome do paciente, também pode ser útil para verificar duplicatas
# - `DT_NOTIFIC` → data da notificação do caso (preenchimento da ficha de notificação)
# - `VG_ENC` → encerramento do caso (se confirmado por sequenciamento genômico, sugestivo ou 5 - descartado)
# - `CLASSI_FIN` → diagnóstico final do caso (tipo de SRAG diagnosticada)
# - `EVOLUCAO` → evolução do caso
#     - 1 - cura | 2 - óbito | 3 - óbito por outras causas | 9-ignorado
# - `UTI` → se o paciente foi internado em UTI
#     - 1 - sim | 2 - não | 9 - ignorado
# - `VACINA` → se o paciente era vacinado ou não contra gripe (checagem de caderneta ou informação fornecida pelo paciente)
#     - 1 - sim | 2 - não | 9 - ignorado
# - `VACINA_COV` → se o paciente recebeu vacina ou não (COVID - checagem da caderneta)
#     - 1 - sim | 2 - não | 9 - ignorado
#
# #### Também, foram selecionadas outras colunas que podem ser úteis (para filtros e estatísticas):
#
# - `DT_NASC` → data de nascimento
# - `NU_IDADE_N` → idade numérica
# - `CS_SEXO` → sexo
# - `CS_ZONA` → zona urbana/rural
# - `CO_MUN_RES` → município de residência (opcional para agregação por cidade)
# - `CO_MUN_NOT` → município de notificação
# - `SG_UF` → estado
#
# **Justificativa:** informações demográficas e geográficas ajudam em agregações e análises complementares.

# %% [markdown]
# Selecionando apenas as colunas desejadas

# %%
# Lista de todas as colunas que serão mantidas
cols_to_keep = [
    "NU_NOTIFIC", "DT_NOTIFIC", "VG_ENC" ,"CLASSI_FIN", "EVOLUCAO", "DT_ENCERRA",
    "UTI", "VACINA", "VACINA_COV", "DT_NASC", "NU_IDADE_N",
    "CS_SEXO", "CS_ZONA", "CO_MUN_RES", "CO_MUN_NOT", "SG_UF",
]

# Filtrando todos os DataFrames do dicionário
all_data_dict_filtered = {year: df[cols_to_keep].copy() for year, df in all_data_dict.items()}

# %% [markdown]
# Gerando um dataframe único com a informação de todos os anos

# %%
df_srag = pd.concat(
    all_data_dict_filtered.values(),
    keys=all_data_dict_filtered.keys(),
    names=["source", None]
).reset_index(level="source").reset_index(drop=True)

# %% [markdown]
# Checando se a operação foi bem sucedida

# %%
for df, values in all_data_dict_filtered.items():

    print(f"{df} : {len(values)} values")
# Out:
# srag_19 : 48961 values
# srag_20 : 1206920 values
# srag_21 : 1745672 values
# srag_22 : 560577 values
# srag_23 : 279453 values
# srag_24 : 267984 values
# srag_25 : 256401 values

# %%
df_srag["source"].value_counts(dropna=False).reset_index().sort_values(by="source")
# Out:
#     source    count
# 6  srag_19    48961
# 1  srag_20  1206920
# 0  srag_21  1745672
# 2  srag_22   560577
# 3  srag_23   279453
# 4  srag_24   267984
# 5  srag_25   256401

# %% [markdown]
# ## Análise qualitativa dos dados

# %%
df_srag.stb.missing()
# Out:
#             missing    total    percent
# VG_ENC      4358216  4365968  99.822445
# VACINA_COV  1531260  4365968  35.072635
# VACINA      1181001  4365968  27.050152
# UTI          574681  4365968  13.162740
# CS_ZONA      444682  4365968  10.185187
# EVOLUCAO     327471  4365968   7.500536
# DT_ENCERRA   315672  4365968   7.230287
# CLASSI_FIN   169612  4365968   3.884866
# CO_MUN_NOT    10581  4365968   0.242352
# DT_NASC        3880  4365968   0.088869
# CO_MUN_RES      768  4365968   0.017591
# SG_UF           768  4365968   0.017591
# CS_SEXO           0  4365968   0.000000
# NU_IDADE_N        0  4365968   0.000000
# NU_NOTIFIC        0  4365968   0.000000
# DT_NOTIFIC        0  4365968   0.000000
# source            0  4365968   0.000000

# %% [markdown]
# VG_ENC com muitos nulos, avaliando a distribuição:

# %%
df_srag["VG_ENC"].value_counts(dropna=False)
# Out:
# VG_ENC
# NaN    4358216
# 3.0       4796
# 1.0       1896
# 5.0        874
# 4.0        127
# 2.0         59
# Name: count, dtype: int64

# %% [markdown]
# Casos com o valor 5 (descartado) em tese podem ser eliminados da base. Depois disso, a coluna não tem mais utilidade.

# %%
df_srag = df_srag[df_srag["VG_ENC"] != 5].copy()
df_srag = df_srag.drop(columns="VG_ENC")

# %% [markdown]
# Avaliando a necessidade de utilizar ambas as colunas VACINA e VACINA_COV

# %%
df_srag["VACINA"].value_counts(dropna=False)
# Out:
# VACINA
# 2.0    1405254
# 9.0    1304791
# NaN    1180834
# 1.0     474215
# Name: count, dtype: int64

# %%
df_srag["VACINA_COV"].value_counts(dropna=False)
# Out:
# VACINA_COV
# NaN    1531260
# 2.0    1236045
# 1.0    1230921
# 9.0     366868
# Name: count, dtype: int64

# %%
df_srag[df_srag["VACINA_COV"] == 1]["VACINA"].value_counts(dropna=False)
# Out:
# VACINA
# 2.0    418007
# NaN    312802
# 9.0    311443
# 1.0    188669
# Name: count, dtype: int64

# %% [markdown]
# Pelo comportamento dos dados, são informações complementares.
#
# Em um primeiro momento, entende-se que os valores nulos podem ser interpretados com o rótulo 9 - ignorado/sem informação
#
# O mesmo se aplica para as colunas `UTI`| `CS_ZONA`| `EVOLUCAO`|

# %%
df_srag["VACINA"] = df_srag["VACINA"].fillna(9)
df_srag["VACINA_COV"] = df_srag["VACINA_COV"].fillna(9)
df_srag["UTI"] = df_srag["UTI"].fillna(9)
df_srag["CS_ZONA"] = df_srag["CS_ZONA"].fillna(9)
df_srag["EVOLUCAO"] = df_srag["EVOLUCAO"].fillna(9)

# %% [markdown]
# Checando eventuais notificações duplicadas

# %%
abs(df_srag['NU_NOTIFIC'].nunique() - len(df_srag))
# Out:
# 11

# %% [markdown]
# Existem notificações duplicadas, mas casos bem pontuais (9). Verificando os casos

# %%
df_srag[df_srag["NU_NOTIFIC"].duplicated(keep=False)].sort_values(by="NU_NOTIFIC")
# Out:
#           source      NU_NOTIFIC  DT_NOTIFIC  CLASSI_FIN  EVOLUCAO  \
# 4101908  srag_24  31735935004234  2024-01-03         NaN       9.0
# 4110055  srag_25  31735935004234  2025-01-03         4.0       1.0
# 4104124  srag_24  31736722248953  2025-01-12         4.0       2.0
# 4112461  srag_25  31736722248953  2025-01-12         4.0       3.0
# 4106818  srag_24  31738932515531  2024-02-07         4.0       9.0
# 4123097  srag_25  31738932515531  2025-02-07         4.0       1.0
# 4109076  srag_24  31743770891762  2024-04-04         NaN       9.0
# 4155998  srag_25  31743770891762  2025-04-04         4.0       2.0
# 4109180  srag_24  31744397861067  2025-04-11         4.0       1.0
# 4162344  srag_25  31744397861067  2025-04-11         4.0       1.0
# 4109220  srag_24  31744827529781  2025-04-14         NaN       9.0
# 4166355  srag_25  31744827529781  2025-04-14         4.0       1.0
# 4109235  srag_24  31745324608735  2025-04-20         4.0       2.0
# 4168400  srag_25  31745324608735  2025-04-20         4.0       2.0
# 4109291  srag_24  31745519106567  2025-04-24         4.0       1.0
# 4172812  srag_25  31745519106567  2025-04-24         4.0       1.0
# 4182445  srag_25  31746458224089  2025-05-05         5.0       1.0
# 4109379  srag_24  31746458224089  2025-05-05         5.0       1.0
# 4215961  srag_25  31748270369373  2025-05-26         1.0       9.0
# 4109457  srag_24  31748270369373  2025-05-26         1.0       9.0
# 4109547  srag_24  31750216000318  2024-06-17         NaN       9.0
# 4261041  srag_25  31750216000318  2025-06-17         1.0       1.0
#
#          DT_ENCERRA  UTI  VACINA  VACINA_COV     DT_NASC  NU_IDADE_N CS_SEXO  \
# 4101908         NaN  9.0     9.0         2.0  2007-12-23          16       F
# 4110055  2025-07-25  9.0     9.0         2.0  2007-12-23          16       F
# 4104124  2025-01-12  9.0     1.0         1.0  1973-01-14          50       M
# 4112461  2025-01-12  9.0     1.0         1.0  1973-01-14          51       M
# 4106818         NaN  2.0     9.0         2.0  2018-11-19           5       M
# 4123097  2025-08-18  2.0     9.0         2.0  2018-11-19           5       M
# 4109076         NaN  9.0     2.0         2.0  1987-02-02          37       M
# 4155998  2025-05-04  9.0     2.0         2.0  1987-02-02          37       M
# 4109180  2025-06-03  1.0     2.0         1.0  1968-02-21          56       M
# 4162344  2025-06-03  1.0     2.0         1.0  1968-02-21          56       M
# 4109220         NaN  1.0     1.0         1.0  2020-01-27           4       M
# 4166355  2025-04-16  1.0     2.0         1.0  2020-01-27           5       M
# 4109235  2025-04-24  1.0     2.0         1.0  1956-08-15          68       M
# 4168400  2025-04-24  1.0     2.0         1.0  1956-08-15          68       M
# 4109291  2025-05-02  2.0     2.0         2.0  2023-09-12           7       F
# 4172812  2025-05-02  2.0     1.0         1.0  2023-09-12           7       F
# 4182445  2025-06-10  1.0     1.0         1.0  1947-09-03          76       M
# 4109379  2025-06-10  1.0     1.0         1.0  1947-09-03          76       M
# 4215961         NaN  1.0     2.0         1.0  1950-11-14          73       F
# 4109457         NaN  1.0     2.0         1.0  1950-11-14          73       F
# 4109547         NaN  2.0     1.0         2.0  2018-01-24           6       M
# 4261041  2025-08-01  2.0     1.0         2.0  2018-01-24           6       M
#
#          CS_ZONA  CO_MUN_RES  CO_MUN_NOT SG_UF
# 4101908      1.0    230440.0    230440.0    CE
# 4110055      1.0    230440.0    230440.0    CE
# 4104124      1.0    353440.0    353440.0    SP
# 4112461      1.0    353440.0    353440.0    SP
# 4106818      1.0    530040.0    530010.0    DF
# 4123097      1.0    530040.0    530010.0    DF
# 4109076      1.0    351060.0    353440.0    SP
# 4155998      1.0    351060.0    353440.0    SP
# 4109180      1.0    352400.0    352590.0    SP
# 4162344      1.0    352400.0    352590.0    SP
# 4109220      1.0    330455.0    330455.0    RJ
# 4166355      1.0    330455.0    330455.0    RJ
# 4109235      1.0    353440.0    353440.0    SP
# 4168400      1.0    353440.0    353440.0    SP
# 4109291      9.0    330455.0    330455.0    RJ
# 4172812      1.0    330455.0    330455.0    RJ
# 4182445      1.0    530090.0    530010.0    DF
# 4109379      1.0    530090.0    530010.0    DF
# 4215961      9.0    355030.0    355030.0    SP
# 4109457      9.0    355030.0    355030.0    SP
# 4109547      1.0    291390.0    291390.0    BA
# 4261041      1.0    291390.0    291390.0    BA

# %% [markdown]
# Eliminando duplicatas gerais (informações/ linhas inteiras duplicadas)

# %%
len(df_srag)
# Out:
# 4365094

# %%
columns_to_consider = [col for col in df_srag.columns if "source" not in col]

df_srag = df_srag.drop_duplicates(subset=columns_to_consider)

# %%
len(df_srag)
# Out:
# 4365090

# %%
df_srag[df_srag["NU_NOTIFIC"].duplicated(keep=False)].sort_values(by="NU_NOTIFIC")
# Out:
#           source      NU_NOTIFIC  DT_NOTIFIC  CLASSI_FIN  EVOLUCAO  \
# 4101908  srag_24  31735935004234  2024-01-03         NaN       9.0
# 4110055  srag_25  31735935004234  2025-01-03         4.0       1.0
# 4104124  srag_24  31736722248953  2025-01-12         4.0       2.0
# 4112461  srag_25  31736722248953  2025-01-12         4.0       3.0
# 4106818  srag_24  31738932515531  2024-02-07         4.0       9.0
# 4123097  srag_25  31738932515531  2025-02-07         4.0       1.0
# 4109076  srag_24  31743770891762  2024-04-04         NaN       9.0
# 4155998  srag_25  31743770891762  2025-04-04         4.0       2.0
# 4109220  srag_24  31744827529781  2025-04-14         NaN       9.0
# 4166355  srag_25  31744827529781  2025-04-14         4.0       1.0
# 4109291  srag_24  31745519106567  2025-04-24         4.0       1.0
# 4172812  srag_25  31745519106567  2025-04-24         4.0       1.0
# 4109547  srag_24  31750216000318  2024-06-17         NaN       9.0
# 4261041  srag_25  31750216000318  2025-06-17         1.0       1.0
#
#          DT_ENCERRA  UTI  VACINA  VACINA_COV     DT_NASC  NU_IDADE_N CS_SEXO  \
# 4101908         NaN  9.0     9.0         2.0  2007-12-23          16       F
# 4110055  2025-07-25  9.0     9.0         2.0  2007-12-23          16       F
# 4104124  2025-01-12  9.0     1.0         1.0  1973-01-14          50       M
# 4112461  2025-01-12  9.0     1.0         1.0  1973-01-14          51       M
# 4106818         NaN  2.0     9.0         2.0  2018-11-19           5       M
# 4123097  2025-08-18  2.0     9.0         2.0  2018-11-19           5       M
# 4109076         NaN  9.0     2.0         2.0  1987-02-02          37       M
# 4155998  2025-05-04  9.0     2.0         2.0  1987-02-02          37       M
# 4109220         NaN  1.0     1.0         1.0  2020-01-27           4       M
# 4166355  2025-04-16  1.0     2.0         1.0  2020-01-27           5       M
# 4109291  2025-05-02  2.0     2.0         2.0  2023-09-12           7       F
# 4172812  2025-05-02  2.0     1.0         1.0  2023-09-12           7       F
# 4109547         NaN  2.0     1.0         2.0  2018-01-24           6       M
# 4261041  2025-08-01  2.0     1.0         2.0  2018-01-24           6       M
#
#          CS_ZONA  CO_MUN_RES  CO_MUN_NOT SG_UF
# 4101908      1.0    230440.0    230440.0    CE
# 4110055      1.0    230440.0    230440.0    CE
# 4104124      1.0    353440.0    353440.0    SP
# 4112461      1.0    353440.0    353440.0    SP
# 4106818      1.0    530040.0    530010.0    DF
# 4123097      1.0    530040.0    530010.0    DF
# 4109076      1.0    351060.0    353440.0    SP
# 4155998      1.0    351060.0    353440.0    SP
# 4109220      1.0    330455.0    330455.0    RJ
# 4166355      1.0    330455.0    330455.0    RJ
# 4109291      9.0    330455.0    330455.0    RJ
# 4172812      1.0    330455.0    330455.0    RJ
# 4109547      1.0    291390.0    291390.0    BA
# 4261041      1.0    291390.0    291390.0    BA

# %% [markdown]
# Eliminando duplicatas que possuem data de encerramento nulas (informação mais recente disponível na base)

# %%
df_srag = df_srag[
    ~(
        (df_srag["NU_NOTIFIC"].duplicated(keep=False))
        &
        (df_srag["DT_ENCERRA"].isna())
    )
].copy()

# %%
df_srag[df_srag["NU_NOTIFIC"].duplicated(keep=False)].sort_values(by="NU_NOTIFIC")
# Out:
#           source      NU_NOTIFIC  DT_NOTIFIC  CLASSI_FIN  EVOLUCAO  \
# 4104124  srag_24  31736722248953  2025-01-12         4.0       2.0
# 4112461  srag_25  31736722248953  2025-01-12         4.0       3.0
# 4109291  srag_24  31745519106567  2025-04-24         4.0       1.0
# 4172812  srag_25  31745519106567  2025-04-24         4.0       1.0
#
#          DT_ENCERRA  UTI  VACINA  VACINA_COV     DT_NASC  NU_IDADE_N CS_SEXO  \
# 4104124  2025-01-12  9.0     1.0         1.0  1973-01-14          50       M
# 4112461  2025-01-12  9.0     1.0         1.0  1973-01-14          51       M
# 4109291  2025-05-02  2.0     2.0         2.0  2023-09-12           7       F
# 4172812  2025-05-02  2.0     1.0         1.0  2023-09-12           7       F
#
#          CS_ZONA  CO_MUN_RES  CO_MUN_NOT SG_UF
# 4104124      1.0    353440.0    353440.0    SP
# 4112461      1.0    353440.0    353440.0    SP
# 4109291      9.0    330455.0    330455.0    RJ
# 4172812      1.0    330455.0    330455.0    RJ

# %% [markdown]
# Eliminando duplicatas por idade (considerar idade mais velha -> informação mais recente)

# %%
len(df_srag)
# Out:
# 4365085

# %%
columns_to_consider = [col for col in df_srag.columns if "source" not in col and "NU_IDADE_N" not in col and "EVOLUCAO" not in col]

# %%
df_srag = df_srag.sort_values(by=["NU_IDADE_N"], ascending=False).drop_duplicates(subset=columns_to_consider)

# %%
len(df_srag)
# Out:
# 4365084

# %%
df_srag[df_srag["NU_NOTIFIC"].duplicated(keep=False)].sort_values(by="NU_NOTIFIC")
# Out:
#           source      NU_NOTIFIC  DT_NOTIFIC  CLASSI_FIN  EVOLUCAO  \
# 4109291  srag_24  31745519106567  2025-04-24         4.0       1.0
# 4172812  srag_25  31745519106567  2025-04-24         4.0       1.0
#
#          DT_ENCERRA  UTI  VACINA  VACINA_COV     DT_NASC  NU_IDADE_N CS_SEXO  \
# 4109291  2025-05-02  2.0     2.0         2.0  2023-09-12           7       F
# 4172812  2025-05-02  2.0     1.0         1.0  2023-09-12           7       F
#
#          CS_ZONA  CO_MUN_RES  CO_MUN_NOT SG_UF
# 4109291      9.0    330455.0    330455.0    RJ
# 4172812      1.0    330455.0    330455.0    RJ

# %% [markdown]
# Eliminando duplicatas por vacinação ou não (caso todas as outras informações sejam iguais)
#
# Nesse caso, considera-se a mais recente como positivo (vacinado)

# %%
columns_to_consider = [col for col in df_srag.columns if "source" not in col and "VACINA" not in col and "VACINA_COV" not in col and "CS_ZONA" not in col]

# %%
len(df_srag)
# Out:
# 4365084

# %%
df_srag = df_srag.sort_values(by=["VACINA"]).drop_duplicates(subset=columns_to_consider)

df_srag = df_srag.sort_values(by=["VACINA_COV"]).drop_duplicates(subset=columns_to_consider)

# %%
len(df_srag)
# Out:
# 4365083

# %%
df_srag["NU_NOTIFIC"].nunique() == len(df_srag)
# Out:
# True

# %% [markdown]
# Sem mais duplicatas.
#
# Exportando versão final para cálculo de métricas

# %% [markdown]
# Relizando um filtro final para conter apenas dados de 2025 e 2024 (diminuir tamanho do arquivo)

# %%
df_srag["source"].value_counts(dropna=False)
# Out:
# source
# srag_21    1745665
# srag_20    1206918
# srag_22     560558
# srag_23     279067
# srag_24     267682
# srag_25     256232
# srag_19      48961
# Name: count, dtype: int64

# %%
df_srag = df_srag[df_srag["source"].isin(["srag_24", "srag_25"])].copy()

# %%
df_srag["source"].value_counts(dropna=False)
# Out:
# source
# srag_24    267682
# srag_25    256232
# Name: count, dtype: int64

# %% [markdown]
# Convertendo a coluna de data para datetime e ordenando o dataframe com base nela

# %%
df_srag["DT_NOTIFIC"] = pd.to_datetime(df_srag["DT_NOTIFIC"], format="%Y-%m-%d")

df_srag = df_srag.sort_values(by="DT_NOTIFIC")

# %% [markdown]
# Eliminando a última data para evitar problemas (dados que podem ter sido inseridos no meio do dia, por exemplo)

# %%
last_date = df_srag["DT_NOTIFIC"].max()

df_srag = df_srag[df_srag["DT_NOTIFIC"] != last_date].copy()

# %%
EXP_DIR = Path("../data/processed")  

df_srag.to_parquet(f"{EXP_DIR}/df_srag.parquet")
